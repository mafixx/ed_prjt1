# %%
#import pandas as pd
#print("OK")
# Out:
# OK

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
conditions = pd.read_csv('../../data/aula_2_banco_de_dados/conditions.csv')
encounters = pd.read_csv('../../data/aula_2_banco_de_dados/encounters.csv')
patients = pd.read_csv('../../data/aula_2_banco_de_dados/patients.csv')

# %%
print("Conditions shape: ", conditions.shape)
print("Encounters shape: ", encounters.shape)
print("Patients shape: ", patients.shape)
# Out:
# Conditions shape:  (3541, 7)
# Encounters shape:  (5745, 15)
# Patients shape:  (111, 28)

# %%
print("DADOS DE PACIENTES")
display(patients.head(2), patients.tail(2))

print("\nDADOS DE ENCONTROS (CONSULTA MÉDICA OU IDA AO HOSPITAL)")
display(encounters.head(2), encounters.tail(2))

print("\nINFORMAÇÕES GERAIS DOS PACIENTES, INCLUINDO SOCIAIS")
display(conditions.head(2), conditions.tail(2))
# Out:
# DADOS DE PACIENTES
#                                      Id   BIRTHDATE DEATHDATE          SSN  \
# 0  412bf1a0-3e57-01f2-7e69-7bc2cbd1acd3  1982-11-02       NaN  999-53-6582
# 1  28312ae6-e826-7ac3-e44d-1a766d71fc08  2007-12-01       NaN  999-79-5518
#
#      DRIVERS    PASSPORT PREFIX    FIRST MIDDLE         LAST SUFFIX MAIDEN  \
# 0  S99910791  X84728254X    Mr.  Boyd728    NaN  Weissnat378    NaN    NaN
# 1  S99938570         NaN    Mr.   Kyle55    NaN    Blanda868    NaN    NaN
#
#   MARITAL   RACE    ETHNICITY GENDER                     BIRTHPLACE  \
# 0       M  white     hispanic      M     Swansea  Massachusetts  US
# 1     NaN  white  nonhispanic      M  Pittsfield  Massachusetts  US
#
#                        ADDRESS       CITY          STATE            COUNTY  \
# 0  191 Runolfsson Drive Apt 19  Westfield  Massachusetts    Hampden County
# 1            224 Gerlach Plaza    Medford  Massachusetts  Middlesex County
#
# ...

# %%
conditions['DESCRIPTION'].head(20)
# Out:
# 0                      Housing unsatisfactory (finding)
# 1                   Received higher education (finding)
# 2                            Social isolation (finding)
# 3                     Medication review due (situation)
# 4     Chronic intractable migraine without aura (dis...
# 5                        Full-time employment (finding)
# 6                      Limited social contact (finding)
# 7                        Part-time employment (finding)
# 8      Reports of violence in the environment (finding)
# 9                    Acute viral pharyngitis (disorder)
# 10                           Viral sinusitis (disorder)
# 11                       Full-time employment (finding)
# 12                           Viral sinusitis (disorder)
# 13            Chronic obstructive bronchitis (disorder)
# 14                    Medication review due (situation)
# 15                                     Stress (finding)
# 16                    Medication review due (situation)
# ...
